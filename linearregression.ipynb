# %%
# Install the scikit-learn, numpy and matplotlab packages.
# To execute a Linux command inside the notebook, simply add an exclamation mark before the command
# numpy requires libatlas-base-dev 
# !sudo apt-get install libatlas-base-dev -y
# !pip3 install -U sklearn numpy matplotlib
# Out:
# libatlas-base-dev is already the newest version (3.10.3-8+rpi1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Requirement already up-to-date: sklearn in /home/pi/.local/lib/python3.7/site-packages (0.0)
# Requirement already up-to-date: numpy in /home/pi/.local/lib/python3.7/site-packages (1.19.4)
# Requirement already up-to-date: matplotlib in /home/pi/.local/lib/python3.7/site-packages (3.3.3)
# Requirement already satisfied, skipping upgrade: scikit-learn in /home/pi/.local/lib/python3.7/site-packages (from sklearn) (0.23.2)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/pi/.local/lib/python3.7/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/pi/.local/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /home/pi/.local/lib/python3.7/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/pi/.local/lib/python3.7/site-packages (from matplotlib) (8.0.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/pi/.local/lib/python3.7/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/pi/.local/lib/python3.7/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/pi/.local/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /home/pi/.local/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.5.4)
# Requirement already satisfied, skipping upgrade: six in /usr/lib/python3/dist-packages (from cycler>=0.10->matplotlib) (1.12.0)

# %%
# import the libraries
import numpy as np
import sklearn
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Setup matplotlib for plotting graphs
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
# Generate some sample training data
X = np.random.rand(100, 1)
y =  3 * X + 4 + np.random.randn(100, 1)

# %%
# Plot the sample training data
plt.plot(X, y, "b.")
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 2, 0, 15])
plt.show()

# %%
# Fit the model with the sample training data
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([3.8288518]), array([[3.26120526]]))

# %%
# Make predictions with the trained model
X_test = np.random.rand(100, 1) # Generate a new set of predictor data
y_test = lin_reg.predict(X_test) # To the prediction with the model
X_test[0], y_test[0] #Look at the first result
# Out:
# (array([0.6359794]), array([5.90291118]))

# %%
# Plot the results
plt.plot(X_test, y_test, "r-", linewidth=2, label="Predictions")
plt.plot(X, y, "b.")
plt.xlabel("$x$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 2, 0, 15])
plt.show()
